# %%
import markovify

# %%
text = open('text.txt', encoding='utf8').read()
text_model = markovify.Text(text)

# %%
#количество предсказаний
count_prediction = 4

# %%
zodiac_signs = {
                1: "Овен",
                2: "Телец", 
                3: "Близнецы",
                4: "Рак",
                5: "Лев",
                6: "Дева",
                7: "Весы",
                8: "Скорпион",
                9: "Стрелец",
                10: "Козерог",
                11: "Водолей",
                12: "Рыбы"
                }

for num, sign in zodiac_signs.items():
    print(f'{num} -> {sign}')

zodiac = int(input("{blue}Введите число с номером знака зодиака: {endcolor}".format(blue="\033[96m", endcolor="\033[0m")))

output = []
forecast = None

if 0 < zodiac < 13:
    for i in range(count_prediction):
        while (not forecast) or (forecast in output):
            forecast = text_model.make_sentence()
        output.append(forecast)
    forecast = zodiac_signs[zodiac] + ', ' + ' '.join(output).replace('.', ';', count_prediction - 1)
    print(forecast.capitalize())
    
else:
    print("Вы ошиблись с числом, запустите программу ещё раз")
# Out:
# 1 -> Овен
# 2 -> Телец
# 3 -> Близнецы
# 4 -> Рак
# 5 -> Лев
# 6 -> Дева
# 7 -> Весы
# 8 -> Скорпион
# 9 -> Стрелец
# 10 -> Козерог
# 11 -> Водолей
# 12 -> Рыбы
# Введите число с номером знака зодиака:  3
# Близнецы, покажите свои лучшие качества и не берите сами; будьте вежливы, тактичны и внимательны к его проблемам; устройте себе маленький праздник, даже если внутри всё кипит; перепроверьте всё несколько раз и не берите сами.

# %%
import telebot
token = open('tg_token.txt', 'r').read()
bot = telebot.TeleBot(token)

# %%
@bot.message_handler(content_types=['text'])
def get_text_messages(message):
  if message.text == "Привет":
      bot.send_message(message.from_user.id, "Привет, сейчас я расскажу тебе гороскоп на сегодня.")
  elif message.text == "/help":
      bot.send_message(message.from_user.id, "Напиши Привет")
  else:
      bot.send_message(message.from_user.id, "Я тебя не понимаю. Напиши /help.")

bot.polling(none_stop=True, interval=0)
